# %%
import pandas as pd

# %% [markdown]
# # Load in 2012 US Voter Data
#
# This is 2012 population and voter registration data
# from the US Census Bureau,
# broken down by state and by age group.

# %%
df = pd.read_csv("2012_US_Voter_data.csv")

# %% [markdown]
# # Initial EDA

# %%
df.head()
# Out:
#      State       Age  Total Population  Citizen Population  Registered Voters  \
# 0  Alabama  18 to 24            439000              428000             212000
# 1  Alabama  25 to 34            576000              535000             359000
# 2  Alabama  35 to 44            615000              582000             410000
# 3  Alabama  45 to 64           1297000             1275000            1051000
# 4  Alabama       65+            667000              660000             523000
#
#    Confirmed Voters
# 0            155000
# 1            271000
# 2            330000
# 3            939000
# 4            459000

# %%
df.tail()
# Out:
#        State       Age  Total Population  Citizen Population  \
# 250  Wyoming  18 to 24             56000               55000
# 251  Wyoming  25 to 34             73000               71000
# 252  Wyoming  35 to 44             68000               66000
# 253  Wyoming  45 to 64            155000              154000
# 254  Wyoming       65+             74000               73000
#
#      Registered Voters  Confirmed Voters
# 250              21000             18000
# 251              44000             39000
# 252              41000             36000
# 253             101000             95000
# 254              61000             59000

# %%
df.sample(10)
# Out:
#                     State       Age  Total Population  Citizen Population  \
# 60                  Idaho  18 to 24            130000              121000
# 186                Oregon  25 to 34            461000              399000
# 99                  Maine       65+            219000              215000
# 107         Massachusetts  35 to 44            888000              783000
# 41   District Of Columbia  25 to 34            154000              133000
# 189                Oregon       65+            616000              604000
# 8                  Alaska  45 to 64            186000              182000
# 81                 Kansas  25 to 34            406000              359000
# 78                   Iowa  45 to 64            828000              812000
# 23             California  45 to 64           9356000             7827000
#
#      Registered Voters  Confirmed Voters
# 60               51000             39000
# 186             256000            215000
# 99              187000            170000
# 107             580000            530000
# 41              114000            102000
# 189             513000            491000
# 8               144000            122000
# 81              236000            172000
# 78              652000            586000
# 23             5459000           4926000

# %%
df.columns
# Out:
# Index(['State', 'Age', 'Total Population', 'Citizen Population',
#        'Registered Voters', 'Confirmed Voters'],
#       dtype='object')

# %%
df. describe()
# Out:
#        Total Population  Citizen Population  Registered Voters  \
# count      2.550000e+02        2.550000e+02       2.550000e+02
# mean       9.225451e+05        8.434706e+05       6.006000e+05
# std        1.157013e+06        1.007374e+06       7.203145e+05
# min        5.600000e+04        5.500000e+04       2.100000e+04
# 25%        2.385000e+05        2.240000e+05       1.465000e+05
# 50%        5.680000e+05        5.400000e+05       3.710000e+05
# 75%        1.159000e+06        1.029000e+06       7.655000e+05
# max        9.356000e+06        7.827000e+06       5.459000e+06
#
#        Confirmed Voters
# count      2.550000e+02
# mean       5.213804e+05
# std        6.413869e+05
# min        1.800000e+04
# 25%        1.285000e+05
# 50%        3.030000e+05
# 75%        6.640000e+05
# max        4.926000e+06

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255 entries, 0 to 254
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               255 non-null    object
#  1   Age                 255 non-null    object
#  2   Total Population    255 non-null    int64
#  3   Citizen Population  255 non-null    int64
#  4   Registered Voters   255 non-null    int64
#  5   Confirmed Voters    255 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 12.1+ KB

# %% [markdown]
# # Questions to think about for the US_Voter_2012 dataset
#
# some of the questions that I'd like to
# explore here are things like
#
# 	• how does voter turnout compare across states?
#
# 	• Are certain age ranges more or less likely to vote in general?
#
# 	• And do these trends hold true nationwide,
#
# or are there state specific insights that we can uncover here?

# %% [markdown]
# # Lets look into the "Total Population", "Citizen Population", "Registered Voters", "Confirmed Voters"

# %% [markdown]
# Let's cut our data by state as rows
#
# and pull in some of the metrics like 'Citizen Population' and 'Confirmed Voters'.
#
# For now, let's use citizen population since only citizens can vote and confirmed voters and start there
# and we'll go ahead and format both those as numbers with 1000 separator and no decimal points.
# There we go.
# And finally, I'll sort my states descending by the citizen population.

# %% [markdown]
# So as expected, we see big states like California, Texas, Florida and New York at the top of our
# list.
#
# And then down at the bottom, obviously, are less densely populated states like the Dakotas and Alaska,
# Vermont and Wyoming.

# %%
df.groupby("State")['Citizen Population','Confirmed Voters'].sum().reset_index().sort_values('Confirmed Voters', ascending=False)
# Out:
# /tmp/ipykernel_30840/1432508034.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby("State")['Citizen Population','Confirmed Voters'].sum().reset_index().sort_values('Confirmed Voters', ascending=False)
#                    State  Citizen Population  Confirmed Voters
# 4             California            23418000          13463000
# 43                 Texas            16062000           8643000
# 9                Florida            13326000           8107000
# 32              New York            13081000           7676000
# 38          Pennsylvania             9451000           5824000
# 13              Illinois             8831000           5428000
# 35                  Ohio             8550000           5395000
# 22              Michigan             7228000           4831000
# 33        North Carolina             6711000           4624000
# 10               Georgia             6738000           4168000
# 46              Virginia             5646000           3778000
# 30            New Jersey             5929000           3670000
# 21         Massachusetts             4773000           3382000
# 47            Washington             4833000           3172000
# 49             Wisconsin             4247000           3128000
# 23             Minnesota             3903000           2859000
# 25              Missouri             4409000           2818000
# 14               Indiana             4724000           2801000
# 20              Maryland             4006000           2610000
# 42             Tennessee             4678000           2606000
# 5               Colorado             3543000           2495000
# 2                Arizona             4315000           2412000
# 40        South Carolina             3381000           2187000
# 0                Alabama             3480000           2154000
# 18             Louisiana             3239000           2149000
# 37                Oregon             2807000           1897000
# 17              Kentucky             3193000           1895000
# 24           Mississippi             2130000           1588000
# 6            Connecticut             2500000           1569000
# 15                  Iowa             2232000           1548000
# 36              Oklahoma             2734000           1431000
# 16                Kansas             1974000           1249000
# 3               Arkansas             2110000           1124000
# 28                Nevada             1808000           1048000
# 44                  Utah             1793000           1022000
# 31            New Mexico             1426000            878000
# 27              Nebraska             1297000            799000
# 19                 Maine             1020000            699000
# 48         West Virginia             1443000            689000
# 29         New Hampshire              992000            688000
# 12                 Idaho             1064000            680000
# 26               Montana              754000            495000
# 11                Hawaii              930000            481000
# 39          Rhode Island              751000            469000
# 7               Delaware              642000            430000
# 41          South Dakota              606000            371000
# 8   District Of Columbia              461000            351000
# 34          North Dakota              515000            328000
# 45               Vermont              487000            307000
# 1                 Alaska              495000            289000
# 50               Wyoming              419000            247000

# %% [markdown]
# # Create a calculated field '% Voter Population'
#
# From here, I want to add a calculated field, because what I'm interested in looking at isn't just
#
# the number of citizens and the number of confirmed voters, which is interesting but not entirely surprising.
#
# What I want to do is actually calculate a ratio so that I can see out of the citizen population what
#
# percentage of those actually became confirmed voters.
#
# ${\% Voter Population = \frac{(Confirmed Voters)}{Citizen Population}}$

# %% [markdown]
# ## Lets find the state with the highest '% Voter Population'
#
# at the state level

# %%
df_state_level = df.groupby("State")['Citizen Population','Confirmed Voters'].sum().reset_index()

df_state_level.head(5)
# Out:
# /tmp/ipykernel_30840/751649940.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_state_level = df.groupby("State")['Citizen Population','Confirmed Voters'].sum().reset_index()
#         State  Citizen Population  Confirmed Voters
# 0     Alabama             3480000           2154000
# 1      Alaska              495000            289000
# 2     Arizona             4315000           2412000
# 3    Arkansas             2110000           1124000
# 4  California            23418000          13463000

# %%
df_state_level['% Voter Population - State_Level'] = round((df_state_level['Confirmed Voters'] / df_state_level['Citizen Population'] * 100), 2)

# %%
df_state_level = df_state_level.sort_values(by=['% Voter Population - State_Level'], ascending=False)

# %% [markdown]
# ## the Top 5 states with highest '% Voter Population'
#
# We see District of Columbia or D.C. at the top of the list with a voter population percentage of 76.1%.
#
# That makes sense.
#
# It's the nation's capital.
#
# It's the political heart of the country.
#
# But then you also have states like Mississippi and Wisconsin, which, you know, may come as a surprise
# to some.

# %%
df_state_level.head()
# Out:
#                    State  Citizen Population  Confirmed Voters  \
# 8   District Of Columbia              461000            351000
# 24           Mississippi             2130000           1588000
# 49             Wisconsin             4247000           3128000
# 23             Minnesota             3903000           2859000
# 21         Massachusetts             4773000           3382000
#
#     % Voter Population - State_Level
# 8                              76.14
# 24                             74.55
# 49                             73.65
# 23                             73.25
# 21                             70.86

# %% [markdown]
# ## the Bottom 5 states with lowest '% Voter Population'
#
# Now, scrolling down on the other end of the spectrum, we see West Virginia, Hawaii, Oklahoma and
# Arkansas.
#
# Now, this isn't necessarily the time or place to dig much deeper into why these trends are the way
# they are.
#
# So what actually causes the West Virginia population to be less likely to convert into voters compared
# to Massachusetts or Colorado, for instance?

# %%
df_state_level.tail()
# Out:
#             State  Citizen Population  Confirmed Voters  \
# 43          Texas            16062000           8643000
# 3        Arkansas             2110000           1124000
# 36       Oklahoma             2734000           1431000
# 11         Hawaii              930000            481000
# 48  West Virginia             1443000            689000
#
#     % Voter Population - State_Level
# 43                             53.81
# 3                              53.27
# 36                             52.34
# 11                             51.72
# 48                             47.75

# %% [markdown]
# So maybe things like
#
# 	• income per capita
#
# 	• or education level
#
# 	• or additional demographics
#
# might help to provide some additional context
#
# and give you tools to better understand the why or the driving forces behind
#
# these voter rates that we're seeing here.

# %%
df_state_level
# Out:
#                    State  Citizen Population  Confirmed Voters  \
# 8   District Of Columbia              461000            351000
# 24           Mississippi             2130000           1588000
# 49             Wisconsin             4247000           3128000
# 23             Minnesota             3903000           2859000
# 21         Massachusetts             4773000           3382000
# 5               Colorado             3543000           2495000
# 15                  Iowa             2232000           1548000
# 29         New Hampshire              992000            688000
# 33        North Carolina             6711000           4624000
# 19                 Maine             1020000            699000
# 37                Oregon             2807000           1897000
# 7               Delaware              642000            430000
# 46              Virginia             5646000           3778000
# 22              Michigan             7228000           4831000
# 18             Louisiana             3239000           2149000
# 26               Montana              754000            495000
# 47            Washington             4833000           3172000
# 20              Maryland             4006000           2610000
# 40        South Carolina             3381000           2187000
# 12                 Idaho             1064000            680000
# 25              Missouri             4409000           2818000
# 34          North Dakota              515000            328000
# 16                Kansas             1974000           1249000
# 35                  Ohio             8550000           5395000
# 45               Vermont              487000            307000
# 6            Connecticut             2500000           1569000
# 39          Rhode Island              751000            469000
# 30            New Jersey             5929000           3670000
# 0                Alabama             3480000           2154000
# 10               Georgia             6738000           4168000
# 38          Pennsylvania             9451000           5824000
# 27              Nebraska             1297000            799000
# 31            New Mexico             1426000            878000
# 13              Illinois             8831000           5428000
# 41          South Dakota              606000            371000
# 9                Florida            13326000           8107000
# 17              Kentucky             3193000           1895000
# 14               Indiana             4724000           2801000
# 50               Wyoming              419000            247000
# 32              New York            13081000           7676000
# 1                 Alaska              495000            289000
# 28                Nevada             1808000           1048000
# 4             California            23418000          13463000
# 44                  Utah             1793000           1022000
# 2                Arizona             4315000           2412000
# 42             Tennessee             4678000           2606000
# 43                 Texas            16062000           8643000
# 3               Arkansas             2110000           1124000
# 36              Oklahoma             2734000           1431000
# 11                Hawaii              930000            481000
# 48         West Virginia             1443000            689000
#
#     % Voter Population - State_Level
# 8                              76.14
# 24                             74.55
# 49                             73.65
# 23                             73.25
# 21                             70.86
# 5                              70.42
# 15                             69.35
# 29                             69.35
# 33                             68.90
# 19                             68.53
# 37                             67.58
# 7                              66.98
# 46                             66.91
# 22                             66.84
# 18                             66.35
# 26                             65.65
# 47                             65.63
# 20                             65.15
# 40                             64.69
# 12                             63.91
# 25                             63.91
# 34                             63.69
# 16                             63.27
# 35                             63.10
# 45                             63.04
# 6                              62.76
# 39                             62.45
# 30                             61.90
# 0                              61.90
# 10                             61.86
# 38                             61.62
# 27                             61.60
# 31                             61.57
# 13                             61.47
# 41                             61.22
# 9                              60.84
# 17                             59.35
# 14                             59.29
# 50                             58.95
# 32                             58.68
# 1                              58.38
# 28                             57.96
# 4                              57.49
# 44                             57.00
# 2                              55.90
# 42                             55.71
# 43                             53.81
# 3                              53.27
# 36                             52.34
# 11                             51.72
# 48                             47.75

# %% [markdown]
# # Lets look at the age bucket distribution overall
#
# Now, the next thing that
# I'd like to explore a bit more here to kick things off is
# the composition of the voter population.

# %%
## Let's look at Voting per Age bucket
df_age_level = df.groupby("Age")['Citizen Population','Confirmed Voters'].sum().reset_index()
# new_df = new_df.sort_values(by=['Citizen Population'], ascending=False)
df_age_level
# Out:
# /tmp/ipykernel_30840/2997487765.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_age_level = df.groupby("Age")['Citizen Population','Confirmed Voters'].sum().reset_index()
#         Age  Citizen Population  Confirmed Voters
# 0  18 to 24            27537000          11351000
# 1  25 to 34            35474000          18978000
# 2  35 to 44            34266000          20965000
# 3  45 to 64            76641000          52013000
# 4       65+            41167000          29645000

# %% [markdown]
# ### lets' add calculated field-  '% Voter Population - Age_Level'
#
# This '% Voter Population - Age_Level' is calculated per Age Bucket over all 50 states

# %% [markdown]
# Now, what this tells me is that among all confirmed voters in this data set,
# so in the year 2012,
#
# I know that the largest share of those voters fall into the 45 to 64 range,
# followed by the 65 plus range at 22%.
#
# And on the other end,
# you've got your smallest proportion or share of voters which fall into 18 to 24.

# %%
df_age_level['% Voter Population - Age_Level_overall'] = round((df_age_level['Confirmed Voters'] / df_age_level['Citizen Population'] * 100),2)
df_age_level
# Out:
#         Age  Citizen Population  Confirmed Voters  \
# 0  18 to 24            27537000          11351000
# 1  25 to 34            35474000          18978000
# 2  35 to 44            34266000          20965000
# 3  45 to 64            76641000          52013000
# 4       65+            41167000          29645000
#
#    % Voter Population - Age_Level_overall
# 0                                   41.22
# 1                                   53.50
# 2                                   61.18
# 3                                   67.87
# 4                                   72.01

# %%
# Let's add another calculated field which a % of column total

# %%
total_confirmed_voters = df_age_level['Confirmed Voters'].sum()
total_confirmed_voters
# Out:
# 132952000

# %%
df_age_level['% of Total Confirmed Voters'] = round((df_age_level['Confirmed Voters'] / total_confirmed_voters *100), 2)

# %%
df_age_level.columns
# Out:
# Index(['Age', 'Citizen Population', 'Confirmed Voters',
#        '% Voter Population - Age_Level_overall',
#        '% of Total Confirmed Voters'],
#       dtype='object')

# %%
df_age_level = df_age_level[['Age', 
                             'Citizen Population', 
                             'Confirmed Voters',
                             '% of Total Confirmed Voters',
                             '% Voter Population - Age_Level_overall',
       ]]
df_age_level
# Out:
#         Age  Citizen Population  Confirmed Voters  \
# 0  18 to 24            27537000          11351000
# 1  25 to 34            35474000          18978000
# 2  35 to 44            34266000          20965000
# 3  45 to 64            76641000          52013000
# 4       65+            41167000          29645000
#
#    % of Total Confirmed Voters  % Voter Population - Age_Level_overall
# 0                         8.54                                   41.22
# 1                        14.27                                   53.50
# 2                        15.77                                   61.18
# 3                        39.12                                   67.87
# 4                        22.30                                   72.01

# %% [markdown]
# Now, what this tells me is that among all confirmed voters in this data set,
# so in the year 2012,
#
# I know that the largest share of those voters fall into the 45 to 64 range,
# followed by the 65 plus range at 22%.
#
# And on the other end,
#
# you've got your smallest proportion or share of voters which fall into 18 to 24.
#
# So the youngest voters make up only 8.54% of the total number of confirmed voters nationwide.

# %% [markdown]
# # Lets calculate the '% of Total Confirmed Voters per State'

# %% [markdown]
# ### lets' add calculated field-  '% Voter Population - Age_Level per State'
#
# This '% Voter Population - Age_Level' is calculated per Age Bucket over all 50 states

# %%
df['State'].unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District Of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %%
# for Alabama

test_state = df['State'].unique()[0]
test_state
# Out:
# 'Alabama'

# %%
test_state_df = df[df['State'] == test_state]
test_state_df
# Out:
#      State       Age  Total Population  Citizen Population  Registered Voters  \
# 0  Alabama  18 to 24            439000              428000             212000
# 1  Alabama  25 to 34            576000              535000             359000
# 2  Alabama  35 to 44            615000              582000             410000
# 3  Alabama  45 to 64           1297000             1275000            1051000
# 4  Alabama       65+            667000              660000             523000
#
#    Confirmed Voters
# 0            155000
# 1            271000
# 2            330000
# 3            939000
# 4            459000

# %%
test_state_df['% of Total Confirmed Voters per State'] = round((test_state_df['Confirmed Voters']/test_state_df['Confirmed Voters'].sum()*100),2)
# Out:
# /tmp/ipykernel_30840/2378482979.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_state_df['% of Total Confirmed Voters per State'] = round((test_state_df['Confirmed Voters']/test_state_df['Confirmed Voters'].sum()*100),2)

# %%
test_state_df
# Out:
#      State       Age  Total Population  Citizen Population  Registered Voters  \
# 0  Alabama  18 to 24            439000              428000             212000
# 1  Alabama  25 to 34            576000              535000             359000
# 2  Alabama  35 to 44            615000              582000             410000
# 3  Alabama  45 to 64           1297000             1275000            1051000
# 4  Alabama       65+            667000              660000             523000
#
#    Confirmed Voters  % of Total Confirmed Voters per State
# 0            155000                                   7.20
# 1            271000                                  12.58
# 2            330000                                  15.32
# 3            939000                                  43.59
# 4            459000                                  21.31

# %%
# state_list = df['State'].unique()
# state_list[1:]
# Out:
# array(['Alaska', 'Arizona', 'Arkansas', 'California', 'Colorado',
#        'Connecticut', 'Delaware', 'District Of Columbia', 'Florida',
#        'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana', 'Iowa',
#        'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %%
pd.set_option('display.max_columns', None)

# %%
state_list = df['State'].unique()
df_list = []

for state in state_list:
    # print(state)
    a = df[df['State'] == state]
    a['% of Total Confirmed Voters per State'] = round((a['Confirmed Voters']/a['Confirmed Voters'].sum()*100),2)
    # print(a.head())
    df_list.append(a)
# Out:
# /tmp/ipykernel_30840/1932299257.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['% of Total Confirmed Voters per State'] = round((a['Confirmed Voters']/a['Confirmed Voters'].sum()*100),2)
# /tmp/ipykernel_30840/1932299257.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['% of Total Confirmed Voters per State'] = round((a['Confirmed Voters']/a['Confirmed Voters'].sum()*100),2)
# /tmp/ipykernel_30840/1932299257.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['% of Total Confirmed Voters per State'] = round((a['Confirmed Voters']/a['Confirmed Voters'].sum()*100),2)
# /tmp/ipykernel_30840/1932299257.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['% of Total Confirmed Voters per State'] = round((a['Confirmed Voters']/a['Confirmed Voters'].sum()*100),2)
# /tmp/ipykernel_30840/1932299257.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['% of Total Confirmed Voters per State'] = round((a['Confirmed Voters']/a['Confirmed Voters'].sum()*100),2)
# /tmp/ipykernel_30840/1932299257.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['% of Total Confirmed Voters per State'] = round((a['Confirmed Voters']/a['Confirmed Voters'].sum()*100),2)
# /tmp/ipykernel_30840/1932299257.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['% of Total Confirmed Voters per State'] = round((a['Confirmed Voters']/a['Confirmed Voters'].sum()*100),2)
# /tmp/ipykernel_30840/1932299257.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['% of Total Confirmed Voters per State'] = round((a['Confirmed Voters']/a['Confirmed Voters'].sum()*100),2)
# /tmp/ipykernel_30840/1932299257.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['% of Total Confirmed Voters per State'] = round((a['Confirmed Voters']/a['Confirmed Voters'].sum()*100),2)
# /tmp/ipykernel_30840/1932299257.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['% of Total Confirmed Voters per State'] = round((a['Confirmed Voters']/a['Confirmed Voters'].sum()*100),2)
# /tmp/ipykernel_30840/1932299257.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['% of Total Confirmed Voters per State'] = round((a['Confirmed Voters']/a['Confirmed Voters'].sum()*100),2)
# /tmp/ipykernel_30840/1932299257.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['% of Total Confirmed Voters per State'] = round((a['Confirmed Voters']/a['Confirmed Voters'].sum()*100),2)
# /tmp/ipykernel_30840/1932299257.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['% of Total Confirmed Voters per State'] = round((a['Confirmed Voters']/a['Confirmed Voters'].sum()*100),2)
# /tmp/ipykernel_30840/1932299257.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['% of Total Confirmed Voters per State'] = round((a['Confirmed Voters']/a['Confirmed Voters'].sum()*100),2)
# /tmp/ipykernel_30840/1932299257.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['% of Total Confirmed Voters per State'] = round((a['Confirmed Voters']/a['Confirmed Voters'].sum()*100),2)
# /tmp/ipykernel_30840/1932299257.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['% of Total Confirmed Voters per State'] = round((a['Confirmed Voters']/a['Confirmed Voters'].sum()*100),2)
# /tmp/ipykernel_30840/1932299257.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['% of Total Confirmed Voters per State'] = round((a['Confirmed Voters']/a['Confirmed Voters'].sum()*100),2)
# /tmp/ipykernel_30840/1932299257.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['% of Total Confirmed Voters per State'] = round((a['Confirmed Voters']/a['Confirmed Voters'].sum()*100),2)
# /tmp/ipykernel_30840/1932299257.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['% of Total Confirmed Voters per State'] = round((a['Confirmed Voters']/a['Confirmed Voters'].sum()*100),2)
# /tmp/ipykernel_30840/1932299257.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['% of Total Confirmed Voters per State'] = round((a['Confirmed Voters']/a['Confirmed Voters'].sum()*100),2)
# /tmp/ipykernel_30840/1932299257.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['% of Total Confirmed Voters per State'] = round((a['Confirmed Voters']/a['Confirmed Voters'].sum()*100),2)
# /tmp/ipykernel_30840/1932299257.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['% of Total Confirmed Voters per State'] = round((a['Confirmed Voters']/a['Confirmed Voters'].sum()*100),2)
# /tmp/ipykernel_30840/1932299257.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['% of Total Confirmed Voters per State'] = round((a['Confirmed Voters']/a['Confirmed Voters'].sum()*100),2)
# /tmp/ipykernel_30840/1932299257.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['% of Total Confirmed Voters per State'] = round((a['Confirmed Voters']/a['Confirmed Voters'].sum()*100),2)
# /tmp/ipykernel_30840/1932299257.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['% of Total Confirmed Voters per State'] = round((a['Confirmed Voters']/a['Confirmed Voters'].sum()*100),2)
# /tmp/ipykernel_30840/1932299257.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['% of Total Confirmed Voters per State'] = round((a['Confirmed Voters']/a['Confirmed Voters'].sum()*100),2)
# /tmp/ipykernel_30840/1932299257.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['% of Total Confirmed Voters per State'] = round((a['Confirmed Voters']/a['Confirmed Voters'].sum()*100),2)
# /tmp/ipykernel_30840/1932299257.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['% of Total Confirmed Voters per State'] = round((a['Confirmed Voters']/a['Confirmed Voters'].sum()*100),2)
# /tmp/ipykernel_30840/1932299257.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['% of Total Confirmed Voters per State'] = round((a['Confirmed Voters']/a['Confirmed Voters'].sum()*100),2)
# /tmp/ipykernel_30840/1932299257.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['% of Total Confirmed Voters per State'] = round((a['Confirmed Voters']/a['Confirmed Voters'].sum()*100),2)
# /tmp/ipykernel_30840/1932299257.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['% of Total Confirmed Voters per State'] = round((a['Confirmed Voters']/a['Confirmed Voters'].sum()*100),2)
# /tmp/ipykernel_30840/1932299257.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['% of Total Confirmed Voters per State'] = round((a['Confirmed Voters']/a['Confirmed Voters'].sum()*100),2)
# /tmp/ipykernel_30840/1932299257.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['% of Total Confirmed Voters per State'] = round((a['Confirmed Voters']/a['Confirmed Voters'].sum()*100),2)
# /tmp/ipykernel_30840/1932299257.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['% of Total Confirmed Voters per State'] = round((a['Confirmed Voters']/a['Confirmed Voters'].sum()*100),2)
# /tmp/ipykernel_30840/1932299257.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['% of Total Confirmed Voters per State'] = round((a['Confirmed Voters']/a['Confirmed Voters'].sum()*100),2)
# /tmp/ipykernel_30840/1932299257.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['% of Total Confirmed Voters per State'] = round((a['Confirmed Voters']/a['Confirmed Voters'].sum()*100),2)
# /tmp/ipykernel_30840/1932299257.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['% of Total Confirmed Voters per State'] = round((a['Confirmed Voters']/a['Confirmed Voters'].sum()*100),2)
# /tmp/ipykernel_30840/1932299257.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['% of Total Confirmed Voters per State'] = round((a['Confirmed Voters']/a['Confirmed Voters'].sum()*100),2)
# /tmp/ipykernel_30840/1932299257.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['% of Total Confirmed Voters per State'] = round((a['Confirmed Voters']/a['Confirmed Voters'].sum()*100),2)
# /tmp/ipykernel_30840/1932299257.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['% of Total Confirmed Voters per State'] = round((a['Confirmed Voters']/a['Confirmed Voters'].sum()*100),2)
# /tmp/ipykernel_30840/1932299257.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['% of Total Confirmed Voters per State'] = round((a['Confirmed Voters']/a['Confirmed Voters'].sum()*100),2)
# /tmp/ipykernel_30840/1932299257.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['% of Total Confirmed Voters per State'] = round((a['Confirmed Voters']/a['Confirmed Voters'].sum()*100),2)
# /tmp/ipykernel_30840/1932299257.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['% of Total Confirmed Voters per State'] = round((a['Confirmed Voters']/a['Confirmed Voters'].sum()*100),2)
# /tmp/ipykernel_30840/1932299257.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['% of Total Confirmed Voters per State'] = round((a['Confirmed Voters']/a['Confirmed Voters'].sum()*100),2)
# /tmp/ipykernel_30840/1932299257.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['% of Total Confirmed Voters per State'] = round((a['Confirmed Voters']/a['Confirmed Voters'].sum()*100),2)
# /tmp/ipykernel_30840/1932299257.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['% of Total Confirmed Voters per State'] = round((a['Confirmed Voters']/a['Confirmed Voters'].sum()*100),2)
# /tmp/ipykernel_30840/1932299257.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['% of Total Confirmed Voters per State'] = round((a['Confirmed Voters']/a['Confirmed Voters'].sum()*100),2)
# /tmp/ipykernel_30840/1932299257.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['% of Total Confirmed Voters per State'] = round((a['Confirmed Voters']/a['Confirmed Voters'].sum()*100),2)
# /tmp/ipykernel_30840/1932299257.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['% of Total Confirmed Voters per State'] = round((a['Confirmed Voters']/a['Confirmed Voters'].sum()*100),2)
# /tmp/ipykernel_30840/1932299257.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['% of Total Confirmed Voters per State'] = round((a['Confirmed Voters']/a['Confirmed Voters'].sum()*100),2)
# /tmp/ipykernel_30840/1932299257.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   a['% of Total Confirmed Voters per State'] = round((a['Confirmed Voters']/a['Confirmed Voters'].sum()*100),2)

# %%
df_list[6]
# Out:
#           State       Age  Total Population  Citizen Population  \
# 30  Connecticut  18 to 24            333000              308000
# 31  Connecticut  25 to 34            402000              331000
# 32  Connecticut  35 to 44            441000              382000
# 33  Connecticut  45 to 64           1047000              993000
# 34  Connecticut       65+            503000              486000
#
#     Registered Voters  Confirmed Voters  % of Total Confirmed Voters per State
# 30             145000            123000                                   7.84
# 31             210000            177000                                  11.28
# 32             255000            223000                                  14.21
# 33             768000            695000                                  44.30
# 34             383000            351000                                  22.37

# %%
# next concat list of df into one big dataframe
df_age_level_concat = pd.concat(df_list)

# %%
df_age_level_concat
# Out:
#        State       Age  Total Population  Citizen Population  \
# 0    Alabama  18 to 24            439000              428000
# 1    Alabama  25 to 34            576000              535000
# 2    Alabama  35 to 44            615000              582000
# 3    Alabama  45 to 64           1297000             1275000
# 4    Alabama       65+            667000              660000
# ..       ...       ...               ...                 ...
# 250  Wyoming  18 to 24             56000               55000
# 251  Wyoming  25 to 34             73000               71000
# 252  Wyoming  35 to 44             68000               66000
# 253  Wyoming  45 to 64            155000              154000
# 254  Wyoming       65+             74000               73000
#
#      Registered Voters  Confirmed Voters  \
# 0               212000            155000
# 1               359000            271000
# 2               410000            330000
# 3              1051000            939000
# 4               523000            459000
# ..                 ...               ...
# 250              21000             18000
# 251              44000             39000
# 252              41000             36000
# 253             101000             95000
# 254              61000             59000
#
#      % of Total Confirmed Voters per State
# 0                                     7.20
# 1                                    12.58
# 2                                    15.32
# 3                                    43.59
# 4                                    21.31
# ..                                     ...
# 250                                   7.29
# 251                                  15.79
# 252                                  14.57
# 253                                  38.46
# 254                                  23.89
#
# [255 rows x 7 columns]

# %%
# now merge with state level % vote calculations
df_state_level.head(10)
# Out:
#                    State  Citizen Population  Confirmed Voters  \
# 8   District Of Columbia              461000            351000
# 24           Mississippi             2130000           1588000
# 49             Wisconsin             4247000           3128000
# 23             Minnesota             3903000           2859000
# 21         Massachusetts             4773000           3382000
# 5               Colorado             3543000           2495000
# 15                  Iowa             2232000           1548000
# 29         New Hampshire              992000            688000
# 33        North Carolina             6711000           4624000
# 19                 Maine             1020000            699000
#
#     % Voter Population - State_Level
# 8                              76.14
# 24                             74.55
# 49                             73.65
# 23                             73.25
# 21                             70.86
# 5                              70.42
# 15                             69.35
# 29                             69.35
# 33                             68.90
# 19                             68.53

# %%
df_state_level_premerge = df_state_level[['State', '% Voter Population - State_Level']]

# %%
df_state_level_premerge.head(10)
# Out:
#                    State  % Voter Population - State_Level
# 8   District Of Columbia                             76.14
# 24           Mississippi                             74.55
# 49             Wisconsin                             73.65
# 23             Minnesota                             73.25
# 21         Massachusetts                             70.86
# 5               Colorado                             70.42
# 15                  Iowa                             69.35
# 29         New Hampshire                             69.35
# 33        North Carolina                             68.90
# 19                 Maine                             68.53

# %%
# merge on 'State' Column

merged_df = pd.merge(df_age_level_concat, df_state_level_premerge, on='State')
merged_df
# Out:
#        State       Age  Total Population  Citizen Population  \
# 0    Alabama  18 to 24            439000              428000
# 1    Alabama  25 to 34            576000              535000
# 2    Alabama  35 to 44            615000              582000
# 3    Alabama  45 to 64           1297000             1275000
# 4    Alabama       65+            667000              660000
# ..       ...       ...               ...                 ...
# 250  Wyoming  18 to 24             56000               55000
# 251  Wyoming  25 to 34             73000               71000
# 252  Wyoming  35 to 44             68000               66000
# 253  Wyoming  45 to 64            155000              154000
# 254  Wyoming       65+             74000               73000
#
#      Registered Voters  Confirmed Voters  \
# 0               212000            155000
# 1               359000            271000
# 2               410000            330000
# 3              1051000            939000
# 4               523000            459000
# ..                 ...               ...
# 250              21000             18000
# 251              44000             39000
# 252              41000             36000
# 253             101000             95000
# 254              61000             59000
#
#      % of Total Confirmed Voters per State  % Voter Population - State_Level
# 0                                     7.20                             61.90
# 1                                    12.58                             61.90
# 2                                    15.32                             61.90
# 3                                    43.59                             61.90
# 4                                    21.31                             61.90
# ..                                     ...                               ...
# 250                                   7.29                             58.95
# 251                                  15.79                             58.95
# 252                                  14.57                             58.95
# 253                                  38.46                             58.95
# 254                                  23.89                             58.95
#
# [255 rows x 8 columns]

# %%
merged_df.sort_values(['% Voter Population - State_Level', 'Age'], ascending=[False,True])[:15]
# Out:
#                     State       Age  Total Population  Citizen Population  \
# 40   District Of Columbia  18 to 24             71000               61000
# 41   District Of Columbia  25 to 34            154000              133000
# 42   District Of Columbia  35 to 44             79000               67000
# 43   District Of Columbia  45 to 64            140000              129000
# 44   District Of Columbia       65+             73000               71000
# 120           Mississippi  18 to 24            300000              294000
# 121           Mississippi  25 to 34            397000              390000
# 122           Mississippi  35 to 44            320000              309000
# 123           Mississippi  45 to 64            734000              727000
# 124           Mississippi       65+            416000              410000
# 245             Wisconsin  18 to 24            539000              513000
# 246             Wisconsin  25 to 34            699000              662000
# 247             Wisconsin  35 to 44            714000              695000
# 248             Wisconsin  45 to 64           1552000             1532000
# 249             Wisconsin       65+            847000              845000
#
#      Registered Voters  Confirmed Voters  \
# 40               43000             38000
# 41              114000            102000
# 42               59000             55000
# 43              109000             99000
# 44               60000             57000
# 120             222000            187000
# 121             333000            279000
# 122             255000            222000
# 123             614000            563000
# 124             371000            337000
# 245             308000            287000
# 246             475000            438000
# 247             548000            514000
# 248            1224000           1192000
# 249             763000            697000
#
#      % of Total Confirmed Voters per State  % Voter Population - State_Level
# 40                                   10.83                             76.14
# 41                                   29.06                             76.14
# 42                                   15.67                             76.14
# 43                                   28.21                             76.14
# 44                                   16.24                             76.14
# 120                                  11.78                             74.55
# 121                                  17.57                             74.55
# 122                                  13.98                             74.55
# 123                                  35.45                             74.55
# 124                                  21.22                             74.55
# 245                                   9.18                             73.65
# 246                                  14.00                             73.65
# 247                                  16.43                             73.65
# 248                                  38.11                             73.65
# 249                                  22.28                             73.65

# %%
merged_df.sort_values(['% Voter Population - State_Level', 'Age'], ascending=[False,True])[-15:]
# Out:
#              State       Age  Total Population  Citizen Population  \
# 180       Oklahoma  18 to 24            325000              323000
# 181       Oklahoma  25 to 34            567000              540000
# 182       Oklahoma  35 to 44            433000              418000
# 183       Oklahoma  45 to 64           1001000              980000
# 184       Oklahoma       65+            483000              473000
# 55          Hawaii  18 to 24            107000               91000
# 56          Hawaii  25 to 34            172000              154000
# 57          Hawaii  35 to 44            166000              153000
# 58          Hawaii  45 to 64            343000              317000
# 59          Hawaii       65+            224000              215000
# 240  West Virginia  18 to 24            163000              162000
# 241  West Virginia  25 to 34            213000              210000
# 242  West Virginia  35 to 44            237000              237000
# 243  West Virginia  45 to 64            479000              475000
# 244  West Virginia       65+            361000              359000
#
#      Registered Voters  Confirmed Voters  \
# 180             130000             88000
# 181             296000            184000
# 182             281000            212000
# 183             720000            602000
# 184             378000            345000
# 55               33000             24000
# 56               65000             55000
# 57               83000             69000
# 58              217000            196000
# 59              149000            137000
# 240              78000             37000
# 241             131000             66000
# 242             162000            111000
# 243             326000            253000
# 244             286000            222000
#
#      % of Total Confirmed Voters per State  % Voter Population - State_Level
# 180                                   6.15                             52.34
# 181                                  12.86                             52.34
# 182                                  14.81                             52.34
# 183                                  42.07                             52.34
# 184                                  24.11                             52.34
# 55                                    4.99                             51.72
# 56                                   11.43                             51.72
# 57                                   14.35                             51.72
# 58                                   40.75                             51.72
# 59                                   28.48                             51.72
# 240                                   5.37                             47.75
# 241                                   9.58                             47.75
# 242                                  16.11                             47.75
# 243                                  36.72                             47.75
# 244                                  32.22                             47.75

# %% [markdown]
# And now we have an entirely new set of insights at our fingertips.
#
# So we can drill in state by state and see how these proportions by age ranges differ from place to place.
#
# So DC, for instance, is kind of an interesting story,
#
# which is that the largest share of confirmed
#
# voters within D.C. actually come from the 25 to 34 bucket,
#
# whereas most other states like Mississippi,
#
# Wisconsin, Minnesota show the largest share of voters coming from the 45 to 64 bucket.

# %% [markdown]
# So for whatever reason, the voter population skews a little bit younger in D.C. than it does in many
# of these other states.
#
# And then scrolling down, another interesting insight to see here is that for these low voter population
#
# states like Oklahoma, Hawaii and West Virginia, the smallest proportions are particularly for the
#
# youngest age group, 18 to 24.
#
# So less than 5% of voters in Hawaii fell into the 18 to 24 bucket and only 6% in Oklahoma fell into
#
# that range.
#
# So for whatever reason, the younger populations in these states really don't seem to inclined to get
#
# out there and vote.
#
# So definitely another interesting story, really just starting to scratch the surface into some of the
#
# interesting angles that we can take with this data set.
#
# So that's our kickoff for the US voter case study.

# %% [markdown]
# # Analyzing U.S. Voter Demographics

# %% [markdown]
# ## How many states had a % Voter Population below 55%? Which states?

# %%
merged_df
# Out:
#        State       Age  Total Population  Citizen Population  \
# 0    Alabama  18 to 24            439000              428000
# 1    Alabama  25 to 34            576000              535000
# 2    Alabama  35 to 44            615000              582000
# 3    Alabama  45 to 64           1297000             1275000
# 4    Alabama       65+            667000              660000
# ..       ...       ...               ...                 ...
# 250  Wyoming  18 to 24             56000               55000
# 251  Wyoming  25 to 34             73000               71000
# 252  Wyoming  35 to 44             68000               66000
# 253  Wyoming  45 to 64            155000              154000
# 254  Wyoming       65+             74000               73000
#
#      Registered Voters  Confirmed Voters  \
# 0               212000            155000
# 1               359000            271000
# 2               410000            330000
# 3              1051000            939000
# 4               523000            459000
# ..                 ...               ...
# 250              21000             18000
# 251              44000             39000
# 252              41000             36000
# 253             101000             95000
# 254              61000             59000
#
#      % of Total Confirmed Voters per State  % Voter Population - State_Level
# 0                                     7.20                             61.90
# 1                                    12.58                             61.90
# 2                                    15.32                             61.90
# 3                                    43.59                             61.90
# 4                                    21.31                             61.90
# ..                                     ...                               ...
# 250                                   7.29                             58.95
# 251                                  15.79                             58.95
# 252                                  14.57                             58.95
# 253                                  38.46                             58.95
# 254                                  23.89                             58.95
#
# [255 rows x 8 columns]

# %%
a = merged_df.groupby('State')['% Voter Population - State_Level'].max().reset_index().sort_values('% Voter Population - State_Level', ascending=False)

# %%
a.head()
# Out:
#                    State  % Voter Population - State_Level
# 8   District Of Columbia                             76.14
# 24           Mississippi                             74.55
# 49             Wisconsin                             73.65
# 23             Minnesota                             73.25
# 21         Massachusetts                             70.86

# %%
a[a['% Voter Population - State_Level'] < 55]
# Out:
#             State  % Voter Population - State_Level
# 43          Texas                             53.81
# 3        Arkansas                             53.27
# 36       Oklahoma                             52.34
# 11         Hawaii                             51.72
# 48  West Virginia                             47.75

# %% [markdown]
# As we can see above there are 5 states that have ['% Voter Population - State_Level'] < 55.
#
# The five states are Texas (53.81%), Arkansas (53.27%), Oklahoma (52.34%), Hawaii (51.72%) and West Virginia (47.75%)

# %% [markdown]
# ## How many confirmed voters in California were over 65 years old in 2012?
# ## What percentage does that represent out of the total confirmed voters in California?
# ## What percentage out of the confirmed voters in the entire country?

# %%
merged_df[merged_df['State']=='California']
# Out:
#          State       Age  Total Population  Citizen Population  \
# 20  California  18 to 24           3962000             3479000
# 21  California  25 to 34           5357000             4153000
# 22  California  35 to 44           5030000             3675000
# 23  California  45 to 64           9356000             7827000
# 24  California       65+           4653000             4284000
#
#     Registered Voters  Confirmed Voters  \
# 20            1787000           1447000
# 21            2548000           2070000
# 22            2478000           2118000
# 23            5459000           4926000
# 24            3084000           2902000
#
#     % of Total Confirmed Voters per State  % Voter Population - State_Level
# 20                                  10.75                             57.49
# 21                                  15.38                             57.49
# 22                                  15.73                             57.49
# 23                                  36.59                             57.49
# 24                                  21.56                             57.49

# %% [markdown]
# ### How many confirmed voters in California were over 65 years old in 2012?
#
# From the above dataframe we can see that there are 2,902,000 confirmed voters in California were over 65 years old in 2012.

# %% [markdown]
# ### What percentage does that represent out of the total confirmed voters in California?
#
# From the above dataframe, we can see that 65 years old represented 21.56% of the total confirmed voters in California.

# %%
california = merged_df[merged_df['State']=='California']

# %%
percent_65_older_California_over_country = round((california[california['Age']=='65+']['Confirmed Voters'] / merged_df['Confirmed Voters'].sum() * 100), 2)
percent_65_older_California_over_country
# Out:
# 24    2.18
# Name: Confirmed Voters, dtype: float64

# %% [markdown]
# ### What percentage out of the confirmed voters in the entire country?
#
# From the above calculate, we can see that in California 65 years old represented 2.18% of the total confirmed voters over the entire country.

# %% [markdown]
# # Show both Citizen Population and Confirmed Voters by Age, as % of Column Total.
# # What percentage of the citizen population do 45 to 64 year olds represent?
# # What percentage of the confirmed voter population?

# %%
# we calculated df_age_level with our initial Exploratory Data Analysis

df_age_level
# Out:
#         Age  Citizen Population  Confirmed Voters  \
# 0  18 to 24            27537000          11351000
# 1  25 to 34            35474000          18978000
# 2  35 to 44            34266000          20965000
# 3  45 to 64            76641000          52013000
# 4       65+            41167000          29645000
#
#    % of Total Confirmed Voters  % Voter Population - Age_Level_overall
# 0                         8.54                                   41.22
# 1                        14.27                                   53.50
# 2                        15.77                                   61.18
# 3                        39.12                                   67.87
# 4                        22.30                                   72.01

# %%
df_age_level['% of Total Citizen Population'] = round((df_age_level['Citizen Population'] / df_age_level['Citizen Population'].sum() * 100), 2)

# %%
df_age_level.columns
# Out:
# Index(['Age', 'Citizen Population', 'Confirmed Voters',
#        '% of Total Confirmed Voters', '% Voter Population - Age_Level_overall',
#        '% of Total Citizen Population'],
#       dtype='object')

# %% [markdown]
# ### Show both Citizen Population and Confirmed Voters by Age, as % of Column Total.

# %%
df_age_level = df_age_level[['Age', 
                            'Citizen Population', 
                            '% of Total Citizen Population',
                            'Confirmed Voters',
                            '% of Total Confirmed Voters', 
                            '% Voter Population - Age_Level_overall'
       ]]

df_age_level
# Out:
#         Age  Citizen Population  % of Total Citizen Population  \
# 0  18 to 24            27537000                          12.80
# 1  25 to 34            35474000                          16.49
# 2  35 to 44            34266000                          15.93
# 3  45 to 64            76641000                          35.63
# 4       65+            41167000                          19.14
#
#    Confirmed Voters  % of Total Confirmed Voters  \
# 0          11351000                         8.54
# 1          18978000                        14.27
# 2          20965000                        15.77
# 3          52013000                        39.12
# 4          29645000                        22.30
#
#    % Voter Population - Age_Level_overall
# 0                                   41.22
# 1                                   53.50
# 2                                   61.18
# 3                                   67.87
# 4                                   72.01

# %% [markdown]
# ### What percentage of the citizen population do 45 to 64 year olds represent?
#
# From the above dataframe, we can see that 45 to 65 year olds represent 35.63% of the citizen population of the entire country.

# %% [markdown]
# ### What percentage of the confirmed voter population?
# From the above dataframe, we can see that 45 to 65 year olds represent 35.63% of the Total Confirmed Voters of the entire country.

# %% [markdown]
# # Create a new calculated field named "Voter Turnout" (Confirmed Voters/Registered Voters), formatted as a percentage with 2 decimal points.
# # Which state had the highest voter turnout rate?
# # What about among 18-24 year old voters specifically?

# %%
df_state_level2 = df.groupby("State").sum().reset_index()

df_state_level2.head(5)
# Out:
# /tmp/ipykernel_30840/3732681128.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_state_level2 = df.groupby("State").sum().reset_index()
#         State  Total Population  Citizen Population  Registered Voters  \
# 0     Alabama           3594000             3480000            2555000
# 1      Alaska            516000              495000             360000
# 2     Arizona           4863000             4315000            2811000
# 3    Arkansas           2198000             2110000            1376000
# 4  California          28358000            23418000           15356000
#
#    Confirmed Voters
# 0           2154000
# 1            289000
# 2           2412000
# 3           1124000
# 4          13463000

# %%
df_state_level2['Voter Turnout'] = round((df_state_level2['Confirmed Voters'] / df_state_level2['Registered Voters'] * 100), 2)
df_state_level2.sort_values('Voter Turnout', ascending=False).head(5)
# Out:
#         State  Total Population  Citizen Population  Registered Voters  \
# 5    Colorado           3817000             3543000            2635000
# 49  Wisconsin           4351000             4247000            3318000
# 23  Minnesota           4054000             3903000            3085000
# 50    Wyoming            426000              419000             268000
# 7    Delaware            693000              642000             469000
#
#     Confirmed Voters  Voter Turnout
# 5            2495000          94.69
# 49           3128000          94.27
# 23           2859000          92.67
# 50            247000          92.16
# 7             430000          91.68

# %%
merged_df['Voter Turnout'] = round((merged_df['Confirmed Voters'] / merged_df['Registered Voters'] * 100), 2)
merged_df[merged_df['Age']=='18 to 24'].sort_values('Voter Turnout', ascending=False).head(5)
# Out:
#                     State       Age  Total Population  Citizen Population  \
# 245             Wisconsin  18 to 24            539000              513000
# 25               Colorado  18 to 24            493000              461000
# 115             Minnesota  18 to 24            531000              510000
# 200        South Carolina  18 to 24            474000              451000
# 40   District Of Columbia  18 to 24             71000               61000
#
#      Registered Voters  Confirmed Voters  \
# 245             308000            287000
# 25              278000            259000
# 115             329000            303000
# 200             265000            243000
# 40               43000             38000
#
#      % of Total Confirmed Voters per State  % Voter Population - State_Level  \
# 245                                   9.18                             73.65
# 25                                   10.38                             70.42
# 115                                  10.60                             73.25
# 200                                  11.11                             64.69
# 40                                   10.83                             76.14
#
#      Voter Turnout
# 245          93.18
# 25           93.17
# 115          92.10
# 200          91.70
# 40           88.37

# %% [markdown]
# # As a politician seeking to improve voter turnout rates among young adults (18-24), which particular states would you target first?

# %%
merged_df[merged_df['Age']=='18 to 24'].sort_values('Voter Turnout', ascending=False).tail(5)
# Out:
#              State       Age  Total Population  Citizen Population  \
# 130        Montana  18 to 24             82000               79000
# 205   South Dakota  18 to 24             95000               94000
# 215          Texas  18 to 24           2538000             2249000
# 15        Arkansas  18 to 24            288000              281000
# 240  West Virginia  18 to 24            163000              162000
#
#      Registered Voters  Confirmed Voters  \
# 130              53000             33000
# 205              52000             31000
# 215             971000            572000
# 15              126000             70000
# 240              78000             37000
#
#      % of Total Confirmed Voters per State  % Voter Population - State_Level  \
# 130                                   6.67                             65.65
# 205                                   8.36                             61.22
# 215                                   6.62                             53.81
# 15                                    6.23                             53.27
# 240                                   5.37                             47.75
#
#      Voter Turnout
# 130          62.26
# 205          59.62
# 215          58.91
# 15           55.56
# 240          47.44

# %% [markdown]
# Notes for Pandas Pivot table
#
# https://www.youtube.com/watch?v=5yFox2cReTw
#
# how to sort in pandas pivot table
#
# https://www.statology.org/pandas-pivot-table-sort/
#
# Notes to add a calculated field to a pandas pivot table
#
# https://stackoverflow.com/questions/70281086/how-to-add-calculated-fields-in-pandas-pivot-table

# %%
# this is the visual pivot of the previous dateframe 'df_state_level'
 
pivot_StateLevel_VoterPopPer = pd.pivot_table(data=df, index=['State','Age'], values=['Citizen Population', 'Confirmed Voters'], aggfunc='sum')
p = pivot_StateLevel_VoterPopPer.sort_values(by=['Citizen Population'], ascending=False).reset_index()
p['% Voter Population'] = p['Confirmed Voters'] / p['Citizen Population']
pd.pivot_table(data=p, index=['State','Age']).sort_values(by=['State','% Voter Population'], ascending=[False,False])
# Out:
#                   % Voter Population  Citizen Population  Confirmed Voters
# State   Age
# Wyoming 65+                 0.808219               73000             59000
#         45 to 64            0.616883              154000             95000
#         25 to 34            0.549296               71000             39000
#         35 to 44            0.545455               66000             36000
#         18 to 24            0.327273               55000             18000
# ...                              ...                 ...               ...
# Alabama 45 to 64            0.736471             1275000            939000
#         65+                 0.695455              660000            459000
#         35 to 44            0.567010              582000            330000
#         25 to 34            0.506542              535000            271000
#         18 to 24            0.362150              428000            155000
#
# [255 rows x 3 columns]
