# %%
import pandas as pd

# %% [markdown]
# # Load in 2012 US Voter Data

# %%
df = pd.read_csv("2012_US_Voter_data.csv")

# %% [markdown]
# # Initial EDA

# %%
df.head()
# Out:
#      State       Age  Total Population  Citizen Population  Registered Voters  \
# 0  Alabama  18 to 24            439000              428000             212000
# 1  Alabama  25 to 34            576000              535000             359000
# 2  Alabama  35 to 44            615000              582000             410000
# 3  Alabama  45 to 64           1297000             1275000            1051000
# 4  Alabama       65+            667000              660000             523000
#
#    Confirmed Voters
# 0            155000
# 1            271000
# 2            330000
# 3            939000
# 4            459000

# %%
df.columns
# Out:
# Index(['State', 'Age', 'Total Population', 'Citizen Population',
#        'Registered Voters', 'Confirmed Voters'],
#       dtype='object')

# %%
df. describe()
# Out:
#        Total Population  Citizen Population  Registered Voters  \
# count      2.550000e+02        2.550000e+02       2.550000e+02
# mean       9.225451e+05        8.434706e+05       6.006000e+05
# std        1.157013e+06        1.007374e+06       7.203145e+05
# min        5.600000e+04        5.500000e+04       2.100000e+04
# 25%        2.385000e+05        2.240000e+05       1.465000e+05
# 50%        5.680000e+05        5.400000e+05       3.710000e+05
# 75%        1.159000e+06        1.029000e+06       7.655000e+05
# max        9.356000e+06        7.827000e+06       5.459000e+06
#
#        Confirmed Voters
# count      2.550000e+02
# mean       5.213804e+05
# std        6.413869e+05
# min        1.800000e+04
# 25%        1.285000e+05
# 50%        3.030000e+05
# 75%        6.640000e+05
# max        4.926000e+06

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 255 entries, 0 to 254
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               255 non-null    object
#  1   Age                 255 non-null    object
#  2   Total Population    255 non-null    int64
#  3   Citizen Population  255 non-null    int64
#  4   Registered Voters   255 non-null    int64
#  5   Confirmed Voters    255 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 12.1+ KB

# %% [markdown]
# # Lets look into the "Total Population", "Citizen Population", "Registered Voters", "Confirmed Voters"

# %%
df.groupby("State").sum()
# Out:
# /tmp/ipykernel_13910/3835537063.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby("State").sum()
#                       Total Population  Citizen Population  Registered Voters  \
# State
# Alabama                        3594000             3480000            2555000
# Alaska                          516000              495000             360000
# Arizona                        4863000             4315000            2811000
# Arkansas                       2198000             2110000            1376000
# California                    28358000            23418000           15356000
# Colorado                       3817000             3543000            2635000
# Connecticut                    2726000             2500000            1761000
# Delaware                        693000              642000             469000
# District Of Columbia            517000              461000             385000
# Florida                       15033000            13326000            9102000
# Georgia                        7178000             6738000            4766000
# Hawaii                         1012000              930000             547000
# Idaho                          1129000             1064000             744000
# Illinois                       9650000             8831000            6424000
# Indiana                        4853000             4724000            3270000
# Iowa                           2319000             2232000            1745000
# Kansas                         2120000             1974000            1467000
# Kentucky                       3292000             3193000            2303000
# Louisiana                      3320000             3239000            2498000
# Maine                          1041000             1020000             787000
# Maryland                       4449000             4006000            2888000
# Massachusetts                  5170000             4773000            3758000
# Michigan                       7496000             7228000            5621000
# Minnesota                      4054000             3903000            3085000
# Mississippi                    2167000             2130000            1795000
# Missouri                       4520000             4409000            3383000
# Montana                         769000              754000             553000
# Nebraska                       1371000             1297000             901000
# Nevada                         2040000             1808000            1175000
# New Hampshire                  1029000              992000             752000
# New Jersey                     6729000             5929000            4326000
# New Mexico                     1554000             1426000             979000
# New York                      15066000            13081000            8886000
# North Carolina                 7263000             6711000            5294000
# North Dakota                    528000              515000             384000
# Ohio                           8751000             8550000            6076000
# Oklahoma                       2809000             2734000            1805000
# Oregon                         2999000             2807000            2086000
# Pennsylvania                   9848000             9451000            6794000
# Rhode Island                    818000              751000             552000
# South Carolina                 3516000             3381000            2479000
# South Dakota                    616000              606000             454000
# Tennessee                      4849000             4678000            3211000
# Texas                         18642000            16062000           10750000
# Utah                           1916000             1793000            1137000
# Vermont                         496000              487000             356000
# Virginia                       6095000             5646000            4210000
# Washington                     5230000             4833000            3533000
# West Virginia                  1453000             1443000             983000
# Wisconsin                      4351000             4247000            3318000
# Wyoming                         426000              419000             268000
#
#                       Confirmed Voters
# State
# Alabama                        2154000
# Alaska                          289000
# Arizona                        2412000
# Arkansas                       1124000
# California                    13463000
# Colorado                       2495000
# Connecticut                    1569000
# Delaware                        430000
# District Of Columbia            351000
# Florida                        8107000
# Georgia                        4168000
# Hawaii                          481000
# Idaho                           680000
# Illinois                       5428000
# Indiana                        2801000
# Iowa                           1548000
# Kansas                         1249000
# Kentucky                       1895000
# Louisiana                      2149000
# Maine                           699000
# Maryland                       2610000
# Massachusetts                  3382000
# Michigan                       4831000
# Minnesota                      2859000
# Mississippi                    1588000
# Missouri                       2818000
# Montana                         495000
# Nebraska                        799000
# Nevada                         1048000
# New Hampshire                   688000
# New Jersey                     3670000
# New Mexico                      878000
# New York                       7676000
# North Carolina                 4624000
# North Dakota                    328000
# Ohio                           5395000
# Oklahoma                       1431000
# Oregon                         1897000
# Pennsylvania                   5824000
# Rhode Island                    469000
# South Carolina                 2187000
# South Dakota                    371000
# Tennessee                      2606000
# Texas                          8643000
# Utah                           1022000
# Vermont                         307000
# Virginia                       3778000
# Washington                     3172000
# West Virginia                   689000
# Wisconsin                      3128000
# Wyoming                         247000

# %%
df.groupby("State")['Citizen Population','Confirmed Voters'].sum().reset_index()
# Out:
# /tmp/ipykernel_13910/172697960.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df.groupby("State")['Citizen Population','Confirmed Voters'].sum().reset_index()
#                    State  Citizen Population  Confirmed Voters
# 0                Alabama             3480000           2154000
# 1                 Alaska              495000            289000
# 2                Arizona             4315000           2412000
# 3               Arkansas             2110000           1124000
# 4             California            23418000          13463000
# 5               Colorado             3543000           2495000
# 6            Connecticut             2500000           1569000
# 7               Delaware              642000            430000
# 8   District Of Columbia              461000            351000
# 9                Florida            13326000           8107000
# 10               Georgia             6738000           4168000
# 11                Hawaii              930000            481000
# 12                 Idaho             1064000            680000
# 13              Illinois             8831000           5428000
# 14               Indiana             4724000           2801000
# 15                  Iowa             2232000           1548000
# 16                Kansas             1974000           1249000
# 17              Kentucky             3193000           1895000
# 18             Louisiana             3239000           2149000
# 19                 Maine             1020000            699000
# 20              Maryland             4006000           2610000
# 21         Massachusetts             4773000           3382000
# 22              Michigan             7228000           4831000
# 23             Minnesota             3903000           2859000
# 24           Mississippi             2130000           1588000
# 25              Missouri             4409000           2818000
# 26               Montana              754000            495000
# 27              Nebraska             1297000            799000
# 28                Nevada             1808000           1048000
# 29         New Hampshire              992000            688000
# 30            New Jersey             5929000           3670000
# 31            New Mexico             1426000            878000
# 32              New York            13081000           7676000
# 33        North Carolina             6711000           4624000
# 34          North Dakota              515000            328000
# 35                  Ohio             8550000           5395000
# 36              Oklahoma             2734000           1431000
# 37                Oregon             2807000           1897000
# 38          Pennsylvania             9451000           5824000
# 39          Rhode Island              751000            469000
# 40        South Carolina             3381000           2187000
# 41          South Dakota              606000            371000
# 42             Tennessee             4678000           2606000
# 43                 Texas            16062000           8643000
# 44                  Utah             1793000           1022000
# 45               Vermont              487000            307000
# 46              Virginia             5646000           3778000
# 47            Washington             4833000           3172000
# 48         West Virginia             1443000            689000
# 49             Wisconsin             4247000           3128000
# 50               Wyoming              419000            247000

# %%
new_df = df.groupby("State")['Citizen Population','Confirmed Voters'].sum().reset_index()
new_df = new_df.sort_values(by=['Citizen Population'], ascending=False)
new_df.head(5)
# Out:
# /tmp/ipykernel_13910/325821807.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   new_df = df.groupby("State")['Citizen Population','Confirmed Voters'].sum().reset_index()
#            State  Citizen Population  Confirmed Voters
# 4     California            23418000          13463000
# 43         Texas            16062000           8643000
# 9        Florida            13326000           8107000
# 32      New York            13081000           7676000
# 38  Pennsylvania             9451000           5824000

# %% [markdown]
# ## Let's look at Voting per Age bucket

# %%
new_df = df.groupby("Age")['Citizen Population','Confirmed Voters'].sum().reset_index()
# new_df = new_df.sort_values(by=['Citizen Population'], ascending=False)
new_df
# Out:
# /tmp/ipykernel_13910/3912788721.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   new_df = df.groupby("Age")['Citizen Population','Confirmed Voters'].sum().reset_index()
#         Age  Citizen Population  Confirmed Voters
# 0  18 to 24            27537000          11351000
# 1  25 to 34            35474000          18978000
# 2  35 to 44            34266000          20965000
# 3  45 to 64            76641000          52013000
# 4       65+            41167000          29645000

# %% [markdown]
# ## lets' add another column % Voter Population

# %%
new_df['% Voter Population - Age_Level'] = new_df['Confirmed Voters'] / new_df['Citizen Population'] * 100

# %%
new_df
# Out:
#         Age  Citizen Population  Confirmed Voters  \
# 0  18 to 24            27537000          11351000
# 1  25 to 34            35474000          18978000
# 2  35 to 44            34266000          20965000
# 3  45 to 64            76641000          52013000
# 4       65+            41167000          29645000
#
#    % Voter Population - Age_Level
# 0                       41.220903
# 1                       53.498337
# 2                       61.183097
# 3                       67.865764
# 4                       72.011563

# %%
df
# Out:
#        State       Age  Total Population  Citizen Population  \
# 0    Alabama  18 to 24            439000              428000
# 1    Alabama  25 to 34            576000              535000
# 2    Alabama  35 to 44            615000              582000
# 3    Alabama  45 to 64           1297000             1275000
# 4    Alabama       65+            667000              660000
# ..       ...       ...               ...                 ...
# 250  Wyoming  18 to 24             56000               55000
# 251  Wyoming  25 to 34             73000               71000
# 252  Wyoming  35 to 44             68000               66000
# 253  Wyoming  45 to 64            155000              154000
# 254  Wyoming       65+             74000               73000
#
#      Registered Voters  Confirmed Voters
# 0               212000            155000
# 1               359000            271000
# 2               410000            330000
# 3              1051000            939000
# 4               523000            459000
# ..                 ...               ...
# 250              21000             18000
# 251              44000             39000
# 252              41000             36000
# 253             101000             95000
# 254              61000             59000
#
# [255 rows x 6 columns]

# %%
df['% Voter Population - Age_Level'] = df['Confirmed Voters'] / df['Citizen Population'] * 100

# %%
df
# Out:
#        State       Age  Total Population  Citizen Population  \
# 0    Alabama  18 to 24            439000              428000
# 1    Alabama  25 to 34            576000              535000
# 2    Alabama  35 to 44            615000              582000
# 3    Alabama  45 to 64           1297000             1275000
# 4    Alabama       65+            667000              660000
# ..       ...       ...               ...                 ...
# 250  Wyoming  18 to 24             56000               55000
# 251  Wyoming  25 to 34             73000               71000
# 252  Wyoming  35 to 44             68000               66000
# 253  Wyoming  45 to 64            155000              154000
# 254  Wyoming       65+             74000               73000
#
#      Registered Voters  Confirmed Voters  % Voter Population - Age_Level
# 0               212000            155000                       36.214953
# 1               359000            271000                       50.654206
# 2               410000            330000                       56.701031
# 3              1051000            939000                       73.647059
# 4               523000            459000                       69.545455
# ..                 ...               ...                             ...
# 250              21000             18000                       32.727273
# 251              44000             39000                       54.929577
# 252              41000             36000                       54.545455
# 253             101000             95000                       61.688312
# 254              61000             59000                       80.821918
#
# [255 rows x 7 columns]

# %% [markdown]
# ## Lets find the state with the highest '% Voter Population'
#
# at the state level

# %%
df_state_level = df.groupby("State")['Citizen Population','Confirmed Voters'].sum().reset_index()

df_state_level.head(5)
# Out:
# /tmp/ipykernel_13910/751649940.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_state_level = df.groupby("State")['Citizen Population','Confirmed Voters'].sum().reset_index()
#         State  Citizen Population  Confirmed Voters
# 0     Alabama             3480000           2154000
# 1      Alaska              495000            289000
# 2     Arizona             4315000           2412000
# 3    Arkansas             2110000           1124000
# 4  California            23418000          13463000

# %%
# re code to calculate the '% Voter Population' - at state level / total pop
# df_state_level['% Voter Population - State Level'] = df_state_level['Confirmed Voters'] / df_state_level['Citizen Population'] * 100

# %%
df_state_level['% Voter Population'] = df_state_level['Confirmed Voters'] / df_state_level['Citizen Population'] * 100

# %%
df_state_level = df_state_level.sort_values(by=['% Voter Population'], ascending=False)

# %% [markdown]
# ## the Top 5 states with highest '% Voter Population'
#
# We see District of Columbia or D.C. at the top of the list with a voter population percentage of 76.1%.
#
# That makes sense.
#
# It's the nation's capital.
#
# It's the political heart of the country.
#
# But then you also have states like Mississippi and Wisconsin, which, you know, may come as a surprise
# to some.

# %% [markdown]
# Notes for Pandas Pivot table
#
# https://www.youtube.com/watch?v=5yFox2cReTw
#
# how to sort in pandas pivot table
#
# https://www.statology.org/pandas-pivot-table-sort/
#
# Notes to add a calculated field to a pandas pivot table
#
# https://stackoverflow.com/questions/70281086/how-to-add-calculated-fields-in-pandas-pivot-table

# %%
# this is the visual pivot of the previous dateframe 'df_state_level'
 
pivot_StateLevel_VoterPopPer = pd.pivot_table(data=df, index=['State','Age'], values=['Citizen Population', 'Confirmed Voters'], aggfunc='sum')
p = pivot_StateLevel_VoterPopPer.sort_values(by=['Citizen Population'], ascending=False).reset_index()
p['% Voter Population'] = p['Confirmed Voters'] / p['Citizen Population']
pd.pivot_table(data=p, index=['State','Age']).sort_values(by=['State','% Voter Population'], ascending=[False,False])
# Out:
#                   % Voter Population  Citizen Population  Confirmed Voters
# State   Age
# Wyoming 65+                 0.808219               73000             59000
#         45 to 64            0.616883              154000             95000
#         25 to 34            0.549296               71000             39000
#         35 to 44            0.545455               66000             36000
#         18 to 24            0.327273               55000             18000
# ...                              ...                 ...               ...
# Alabama 45 to 64            0.736471             1275000            939000
#         65+                 0.695455              660000            459000
#         35 to 44            0.567010              582000            330000
#         25 to 34            0.506542              535000            271000
#         18 to 24            0.362150              428000            155000
#
# [255 rows x 3 columns]

# %%
# p.head()

# %%
df_state_level.head()
# Out:
#                    State  Citizen Population  Confirmed Voters  \
# 8   District Of Columbia              461000            351000
# 24           Mississippi             2130000           1588000
# 49             Wisconsin             4247000           3128000
# 23             Minnesota             3903000           2859000
# 21         Massachusetts             4773000           3382000
#
#     % Voter Population
# 8            76.138829
# 24           74.553991
# 49           73.651990
# 23           73.251345
# 21           70.856903

# %% [markdown]
# ## the Bottom 5 states with lowest '% Voter Population'
#
# Now, scrolling down on the other end of the spectrum, we see West Virginia, Hawaii, Oklahoma and
# Arkansas.
#
# Now, this isn't necessarily the time or place to dig much deeper into why these trends are the way
# they are.
#
# So what actually causes the West Virginia population to be less likely to convert into voters compared
# to Massachusetts or Colorado, for instance?

# %%
df_state_level.tail()
# Out:
#             State  Citizen Population  Confirmed Voters  % Voter Population
# 43          Texas            16062000           8643000           53.810235
# 3        Arkansas             2110000           1124000           53.270142
# 36       Oklahoma             2734000           1431000           52.340892
# 11         Hawaii              930000            481000           51.720430
# 48  West Virginia             1443000            689000           47.747748

# %%
df_state_level_premerge = df_state_level[['State', '% Voter Population']]

# %%
df_state_level_premerge = df_state_level_premerge.rename(columns={'% Voter Population':'% Voter Population - State_Level'})

# %%
df_state_level_premerge
# Out:
#                    State  % Voter Population - State_Level
# 8   District Of Columbia                         76.138829
# 24           Mississippi                         74.553991
# 49             Wisconsin                         73.651990
# 23             Minnesota                         73.251345
# 21         Massachusetts                         70.856903
# 5               Colorado                         70.420548
# 15                  Iowa                         69.354839
# 29         New Hampshire                         69.354839
# 33        North Carolina                         68.901803
# 19                 Maine                         68.529412
# 37                Oregon                         67.581047
# 7               Delaware                         66.978193
# 46              Virginia                         66.914630
# 22              Michigan                         66.837299
# 18             Louisiana                         66.347638
# 26               Montana                         65.649867
# 47            Washington                         65.632113
# 20              Maryland                         65.152272
# 40        South Carolina                         64.685004
# 25              Missouri                         63.914720
# 12                 Idaho                         63.909774
# 34          North Dakota                         63.689320
# 16                Kansas                         63.272543
# 35                  Ohio                         63.099415
# 45               Vermont                         63.039014
# 6            Connecticut                         62.760000
# 39          Rhode Island                         62.450067
# 30            New Jersey                         61.899140
# 0                Alabama                         61.896552
# 10               Georgia                         61.858118
# 38          Pennsylvania                         61.623109
# 27              Nebraska                         61.603701
# 31            New Mexico                         61.570827
# 13              Illinois                         61.465293
# 41          South Dakota                         61.221122
# 9                Florida                         60.835960
# 17              Kentucky                         59.348575
# 14               Indiana                         59.292972
# 50               Wyoming                         58.949881
# 32              New York                         58.680529
# 1                 Alaska                         58.383838
# 28                Nevada                         57.964602
# 4             California                         57.489965
# 44                  Utah                         56.999442
# 2                Arizona                         55.898030
# 42             Tennessee                         55.707567
# 43                 Texas                         53.810235
# 3               Arkansas                         53.270142
# 36              Oklahoma                         52.340892
# 11                Hawaii                         51.720430
# 48         West Virginia                         47.747748

# %% [markdown]
# # merge statelevel_premerge and df on 'State'
#
# https://saturncloud.io/blog/how-to-join-two-pandas-dataframes-using-a-specific-column/#:~:text=To%20join%20two%20Pandas%20DataFrames%20using%20a%20specific%20column%2C%20we,left%20join%2C%20and%20right%20join.

# %%
df
# Out:
#        State       Age  Total Population  Citizen Population  \
# 0    Alabama  18 to 24            439000              428000
# 1    Alabama  25 to 34            576000              535000
# 2    Alabama  35 to 44            615000              582000
# 3    Alabama  45 to 64           1297000             1275000
# 4    Alabama       65+            667000              660000
# ..       ...       ...               ...                 ...
# 250  Wyoming  18 to 24             56000               55000
# 251  Wyoming  25 to 34             73000               71000
# 252  Wyoming  35 to 44             68000               66000
# 253  Wyoming  45 to 64            155000              154000
# 254  Wyoming       65+             74000               73000
#
#      Registered Voters  Confirmed Voters  % Voter Population - Age_Level
# 0               212000            155000                       36.214953
# 1               359000            271000                       50.654206
# 2               410000            330000                       56.701031
# 3              1051000            939000                       73.647059
# 4               523000            459000                       69.545455
# ..                 ...               ...                             ...
# 250              21000             18000                       32.727273
# 251              44000             39000                       54.929577
# 252              41000             36000                       54.545455
# 253             101000             95000                       61.688312
# 254              61000             59000                       80.821918
#
# [255 rows x 7 columns]

# %%
merged_df = pd.merge(df, df_state_level_premerge, on='State')
merged_df
# Out:
#        State       Age  Total Population  Citizen Population  \
# 0    Alabama  18 to 24            439000              428000
# 1    Alabama  25 to 34            576000              535000
# 2    Alabama  35 to 44            615000              582000
# 3    Alabama  45 to 64           1297000             1275000
# 4    Alabama       65+            667000              660000
# ..       ...       ...               ...                 ...
# 250  Wyoming  18 to 24             56000               55000
# 251  Wyoming  25 to 34             73000               71000
# 252  Wyoming  35 to 44             68000               66000
# 253  Wyoming  45 to 64            155000              154000
# 254  Wyoming       65+             74000               73000
#
#      Registered Voters  Confirmed Voters  % Voter Population - Age_Level  \
# 0               212000            155000                       36.214953
# 1               359000            271000                       50.654206
# 2               410000            330000                       56.701031
# 3              1051000            939000                       73.647059
# 4               523000            459000                       69.545455
# ..                 ...               ...                             ...
# 250              21000             18000                       32.727273
# 251              44000             39000                       54.929577
# 252              41000             36000                       54.545455
# 253             101000             95000                       61.688312
# 254              61000             59000                       80.821918
#
#      % Voter Population - State_Level
# 0                           61.896552
# 1                           61.896552
# 2                           61.896552
# 3                           61.896552
# 4                           61.896552
# ..                                ...
# 250                         58.949881
# 251                         58.949881
# 252                         58.949881
# 253                         58.949881
# 254                         58.949881
#
# [255 rows x 8 columns]

# %%
merged_df.sort_values('% Voter Population - State_Level', ascending=False)
# Out:
#                     State       Age  Total Population  Citizen Population  \
# 41   District Of Columbia  25 to 34            154000              133000
# 40   District Of Columbia  18 to 24             71000               61000
# 42   District Of Columbia  35 to 44             79000               67000
# 43   District Of Columbia  45 to 64            140000              129000
# 44   District Of Columbia       65+             73000               71000
# ..                    ...       ...               ...                 ...
# 244         West Virginia       65+            361000              359000
# 243         West Virginia  45 to 64            479000              475000
# 242         West Virginia  35 to 44            237000              237000
# 240         West Virginia  18 to 24            163000              162000
# 241         West Virginia  25 to 34            213000              210000
#
#      Registered Voters  Confirmed Voters  % Voter Population - Age_Level  \
# 41              114000            102000                       76.691729
# 40               43000             38000                       62.295082
# 42               59000             55000                       82.089552
# 43              109000             99000                       76.744186
# 44               60000             57000                       80.281690
# ..                 ...               ...                             ...
# 244             286000            222000                       61.838440
# 243             326000            253000                       53.263158
# 242             162000            111000                       46.835443
# 240              78000             37000                       22.839506
# 241             131000             66000                       31.428571
#
#      % Voter Population - State_Level
# 41                          76.138829
# 40                          76.138829
# 42                          76.138829
# 43                          76.138829
# 44                          76.138829
# ..                                ...
# 244                         47.747748
# 243                         47.747748
# 242                         47.747748
# 240                         47.747748
# 241                         47.747748
#
# [255 rows x 8 columns]

# %%
merged_df.groupby(['State'])['% Voter Population - State_Level'].max().sort_values(ascending=False).reset_index()
# Out:
#                    State  % Voter Population - State_Level
# 0   District Of Columbia                         76.138829
# 1            Mississippi                         74.553991
# 2              Wisconsin                         73.651990
# 3              Minnesota                         73.251345
# 4          Massachusetts                         70.856903
# 5               Colorado                         70.420548
# 6                   Iowa                         69.354839
# 7          New Hampshire                         69.354839
# 8         North Carolina                         68.901803
# 9                  Maine                         68.529412
# 10                Oregon                         67.581047
# 11              Delaware                         66.978193
# 12              Virginia                         66.914630
# 13              Michigan                         66.837299
# 14             Louisiana                         66.347638
# 15               Montana                         65.649867
# 16            Washington                         65.632113
# 17              Maryland                         65.152272
# 18        South Carolina                         64.685004
# 19              Missouri                         63.914720
# 20                 Idaho                         63.909774
# 21          North Dakota                         63.689320
# 22                Kansas                         63.272543
# 23                  Ohio                         63.099415
# 24               Vermont                         63.039014
# 25           Connecticut                         62.760000
# 26          Rhode Island                         62.450067
# 27            New Jersey                         61.899140
# 28               Alabama                         61.896552
# 29               Georgia                         61.858118
# 30          Pennsylvania                         61.623109
# 31              Nebraska                         61.603701
# 32            New Mexico                         61.570827
# 33              Illinois                         61.465293
# 34          South Dakota                         61.221122
# 35               Florida                         60.835960
# 36              Kentucky                         59.348575
# 37               Indiana                         59.292972
# 38               Wyoming                         58.949881
# 39              New York                         58.680529
# 40                Alaska                         58.383838
# 41                Nevada                         57.964602
# 42            California                         57.489965
# 43                  Utah                         56.999442
# 44               Arizona                         55.898030
# 45             Tennessee                         55.707567
# 46                 Texas                         53.810235
# 47              Arkansas                         53.270142
# 48              Oklahoma                         52.340892
# 49                Hawaii                         51.720430
# 50         West Virginia                         47.747748

# %% [markdown]
# # grouping by state and age level

# %%
# new_df = df.groupby("Age")['Citizen Population','Confirmed Voters'].sum().reset_index()
# # new_df = new_df.sort_values(by=['Citizen Population'], ascending=False)
# new_df

# %%
pivot1 = pd.pivot_table(data=df, index=['State','Age'])
pivot1

# %%
pivot2 = pd.pivot_table(data=df, index=['State','Age'], values=['Confirmed Voters', 'Citizen Population', '% Voter Population'])
pivot2

# %%
# find list of unique states

df.head()

# %%
df['State'].unique()

# %%
list_of_states = ['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
       'Colorado', 'Connecticut', 'Delaware', 'District Of Columbia',
       'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
       'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
       'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
       'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
       'New Jersey', 'New Mexico', 'New York', 'North Carolina',
       'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
       'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
       'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
       'West Virginia', 'Wisconsin', 'Wyoming']

# %% [markdown]
# # Calculated Field '% Voter Population' per state / country

# %%
# 'Confirmed Voters' total

Total_States_Voter_Population = df['Confirmed Voters'].sum()
Total_States_Voter_Population

# %%
test_state = "Mississippi"

# %%
df[df['State'] == test_state]

# %%
state_df = df[df['State'] ==  test_state]

# %%
NJ_Confirmed_voters = state_df['Confirmed Voters'].sum()

# %%
NJ_CIT_POP = state_df['Citizen Population'].sum()

# %% [markdown]
# # Calculated Field
#
# I'm going to name this voter population percentage.
#
# And again, that's just going to equal the ratio of confirmed voters to the citizen population per state.

# %%
# StateOverALL_PercentVoterPop = f"{round((NJ_Confirmed_voters / Total_States_Voter_Population * 100), 2)} %"
StateOverALL_PercentVoterPop = round((NJ_Confirmed_voters / NJ_CIT_POP * 100), 2)

StateOverALL_PercentVoterPop

# %%
state_df['% Voter Population - State_Level'] = StateOverALL_PercentVoterPop

# %%
state_df

# %% [markdown]
# # Look into how to Join to DataFrames on a column
#
# https://saturncloud.io/blog/how-to-join-two-pandas-dataframes-using-a-specific-column/#:~:text=To%20join%20two%20Pandas%20DataFrames%20using%20a%20specific%20column%2C%20we,left%20join%2C%20and%20right%20join.
